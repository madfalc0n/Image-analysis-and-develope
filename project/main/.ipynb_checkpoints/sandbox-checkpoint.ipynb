# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import geopandas as gpd #https://dailyheumsi.tistory.com/141참고

# %%
#df = gpd.read_file('./data/HangJeongDong_ver20190908.geojson')
#ndf = gpd.read_file('https://github.com/madfalc0n/admdongkor/blob/master/ver2019xxxx_for_update/HangJeongDong_ver2019xxxx_for_update.geojson')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-104-c07f41117b06> in <module>
#       1 #df = gpd.read_file('./data/HangJeongDong_ver20190908.geojson')
# ----> 2 ndf = gpd.read_file('https://github.com/madfalc0n/admdongkor/blob/master/ver2019xxxx_for_update/HangJeongDong_ver2019xxxx_for_update.geojson')
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      66     """
#      67     if _is_url(filename):
# ---> 68         req = _urlopen(filename)
#      69         path_or_bytes = req.read()
#      70         reader = fiona.BytesCollection
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ...

# %%
ndf.head(5)
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...

# %%
df = df[df['adm_nm'].str.contains('서울특별시')]
df.head(3)
# Out:
#    OBJECTID         adm_nm   adm_cd     adm_cd2  \
# 0         1  서울특별시 종로구 사직동  1101053  1111053000
# 1         2  서울특별시 종로구 삼청동  1101054  1111054000
# 2         3  서울특별시 종로구 부암동  1101055  1111055000
#
#                                             geometry
# 0  MULTIPOLYGON (((126.97689 37.57565, 126.97703 ...
# 1  MULTIPOLYGON (((126.98269 37.59507, 126.98337 ...
# 2  MULTIPOLYGON (((126.97585 37.59656, 126.97359 ...

# %%
df.drop(['OBJECTID','adm_cd','adm_cd2'], axis=1,inplace=True)

# %%
df
# Out:
#                     adm_nm                                           geometry
# 0            서울특별시 종로구 사직동  MULTIPOLYGON (((126.97689 37.57565, 126.97703 ...
# 1            서울특별시 종로구 삼청동  MULTIPOLYGON (((126.98269 37.59507, 126.98337 ...
# 2            서울특별시 종로구 부암동  MULTIPOLYGON (((126.97585 37.59656, 126.97359 ...
# 3            서울특별시 종로구 평창동  MULTIPOLYGON (((126.97507 37.63139, 126.97649 ...
# 4            서울특별시 종로구 무악동  MULTIPOLYGON (((126.96067 37.58080, 126.96281 ...
# 5            서울특별시 종로구 교남동  MULTIPOLYGON (((126.96905 37.56819, 126.96801 ...
# 6            서울특별시 종로구 가회동  MULTIPOLYGON (((126.98914 37.59131, 126.98831 ...
# 7    서울특별시 종로구 종로1·2·3·4가동  MULTIPOLYGON (((126.99650 37.58102, 126.99641 ...
# 8        서울특별시 종로구 종로5·6가동  MULTIPOLYGON (((127.01016 37.57157, 127.00959 ...
# 9            서울특별시 종로구 이화동  MULTIPOLYGON (((127.00733 37.58320, 127.00884 ...
# 10          서울특별시 종로구 창신1동  MULTIPOLYGON (((127.01573 37.57298, 127.01882 ...
# ...

# %%
spl_df = df['adm_nm'].str.split(' ')

# %%
jlg = df['']

# %%
df[df['adm_nm'].str.contains('관악구')].boundary.squeeze()
# Out:
# 318    MULTILINESTRING ((126.92987 37.49400, 126.9311...
# 319    MULTILINESTRING ((126.96124 37.49256, 126.9612...
# 320    MULTILINESTRING ((126.96215 37.48524, 126.9614...
# 321    MULTILINESTRING ((126.95277 37.48129, 126.9623...
# 322    MULTILINESTRING ((126.95630 37.48566, 126.9527...
# 323    MULTILINESTRING ((126.97049 37.47537, 126.9707...
# 324    MULTILINESTRING ((126.98172 37.47636, 126.9817...
# 325    MULTILINESTRING ((126.93785 37.48411, 126.9378...
# 326    MULTILINESTRING ((126.93021 37.47534, 126.9294...
# 327    MULTILINESTRING ((126.94655 37.47275, 126.9467...
# 328    MULTILINESTRING ((126.92618 37.48378, 126.9215...
# 329    MULTILINESTRING ((126.93491 37.48640, 126.9342...
# 330    MULTILINESTRING ((126.92298 37.46346, 126.9228...
# 331    MULTILINESTRING ((126.91454 37.48181, 126.9097...
# 332    MULTILINESTRING ((126.95253 37.47110, 126.9531...
# 333    MULTILINESTRING ((126.94339 37.49208, 126.9449...
# ...

# %%
df[df['adm_nm'].str.contains('관악구')].centroid
# Out:
# 318    POINT (126.93259 37.49036)
# 319    POINT (126.95957 37.48941)
# 320    POINT (126.96062 37.48090)
# 321    POINT (126.96005 37.46723)
# 322    POINT (126.95062 37.48412)
# 323    POINT (126.96662 37.47208)
# 324    POINT (126.97664 37.46247)
# 325    POINT (126.93344 37.48060)
# 326    POINT (126.92670 37.47930)
# 327    POINT (126.93921 37.47355)
# 328    POINT (126.91875 37.48563)
# 329    POINT (126.92761 37.48690)
# 330    POINT (126.91827 37.46159)
# 331    POINT (126.90753 37.48294)
# 332    POINT (126.94848 37.45348)
# 333    POINT (126.94221 37.48682)
# 334    POINT (126.95117 37.48951)
# 335    POINT (126.94588 37.47805)
# 336    POINT (126.92105 37.47050)
# 337    POINT (126.93014 37.46067)
# 338    POINT (126.91543 37.47594)
# dtype: geometry

# %%
type(df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df.to_file("./data/seoul_hangjeong.geojson", driver="GeoJSON")
