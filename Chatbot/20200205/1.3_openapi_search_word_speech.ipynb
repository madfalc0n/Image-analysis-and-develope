# %%
import requests
import json
import urllib
from bs4 import BeautifulSoup

# %%
#챗봇
def get_answer(text, sessionId):
    data_send = {
        'query': text, 
        'sessionId': sessionId,
        'lang': 'ko', 
        'timezone' : 'Asia/Seoul'
    }
    data_header = {
        'Authorization': 'Bearer 2f005b4b63804f708b61e84ed03b1970', #개인 키값 
        'Content-Type': 'application/json; charset=utf-8'     
    }

    dialogflow_url = 'https://api.dialogflow.com/v1/query?v=20150910'
    
    res = requests.post(dialogflow_url, data=json.dumps(data_send), headers=data_header) 
    # post 형식으로 전송, url, data 는 문자열(json.dumps는 dict 타입을 문자열로 만듬), 추가할 헤더(dict 타입) 
    # json() 함수는 문자열을 dict 로 변경 json.dumps()는 dict를 문자로
    
    if res.status_code == requests.codes.ok:
        return res.json()    
    return {}


#단어검색
def getmean(word):
    url = "https://search.naver.com/search.naver?where=kdic&query="
    url = url + urllib.parse.quote_plus(word)
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser") 
    output = bs.select('p.txt_box')
    
    return [node.text  for node in output     ]

# %%
a = '갑분싸가 뭐야'
dict = get_answer(a, 'user01') # 다이얼로그에 입력할 내용 , 세션아이디(유저구분용)


answer = dict['result']['fulfillment']['speech']
    
if dict['result']['metadata']['intentName'] == 'weather' and dict['result']['actionIncomplete'] == False:
    date = dict['result']['parameters']['date']
    geo_city = dict['result']['parameters']['geo-city']
    print("날씨 ", data, geo_city)

    
elif dict['result']['metadata']['intentName'] == 'order2' and dict['result']['actionIncomplete'] == False:
    price = {'짜장면':5000 , '짬뽕':6000, '탕수육': 12000}
    params = dict['result']['parameters']['food_number']
    output = [ int(food.get('foodnumber', 1)*price[food["foodname"]]) for food in params]
    print(sum(output))
    
elif dict['result']['metadata']['intentName'] == 'dict' and dict['result']['actionIncomplete'] == False:
    word = dict['result']['parameters']['any']
    print(word)
    print(getmean(word)[0])
# Out:
# 갑분싸
#  ‘갑자기 분위기가 싸해진다.’, ‘갑자기 분위기가 싸해지는데’ 등의 뜻을 가지고 있는 신조어이다. ‘갑자기 분위기가 싸해진다’, ‘갑자기 분위기가 싸해지는데’를 줄여 이르는 신조어이다. ‘갑분싸’는...

# %% [markdown]
# # text to speech

# %%
from gtts import gTTS
r_word = getmean(word)[0]
tts = gTTS(text=r_word, lang='ko') 
tts.save('output.mp3')

# %%
import IPython.display as ipd
ipd.Audio('output.mp3', autoplay=True)#옵션에 autoplay=True 설정지 자동으로 재생
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.core.display import HTML
HTML(
"""
<iframe height="430" width="350" src="https://bot.dialogflow.com/madfalconweb"></iframe>
"""

)
# Out:
# <iframe height="430" width="350" src="https://bot.dialogflow.com/madfalconweb"></iframe>
