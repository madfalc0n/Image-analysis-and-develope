# %%
import cv2, numpy as np
import time
from matplotlib import pyplot as plt

#테서렉트
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract' #테서렉트 설치경로

# %matplotlib inline

def imshow(tit, image) :
    plt.title(tit)    
    if len(image.shape) == 3 :
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    else :
        plt.imshow(image, cmap="gray")
    plt.show()

# %%
image_n = 'credit_card.jpg'
image = cv2.imread('./data/'+image_n,0)  
#img_blur = cv2.GaussianBlur(image, (3,3), 0)
binary = cv2.adaptiveThreshold(image, 255,
          cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
          cv2.THRESH_BINARY, 21, 5)
imshow(" ", binary)
cv2.imwrite("out.png", binary)
# Out:
# True

# %%
binary_output = pytesseract.image_to_string('out.png')
base_str = pytesseract.image_to_string('./data/'+image_n)
imshow('',np.hstack([image, binary ]))
print(str)
# Out:
# Beh el a iee e ) ira)
# Dey)
#
# JOHN SMITH

# %%
# 한글 적용해보기
