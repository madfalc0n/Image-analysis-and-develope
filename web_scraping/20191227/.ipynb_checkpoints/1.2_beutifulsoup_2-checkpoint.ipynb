# %% [markdown]
# ##  1. 네이버 영화 평점 페이지 수 별로 조회

# %%
import requests
from bs4 import BeautifulSoup
import re
import urllib


for n in range(1, 11):
    req = requests.get('https://movie.naver.com/movie/point/af/list.nhn?page='+str(n))    
    html =req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie')
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')    
    for dom in titles :
        movie_title.append(dom.text)
    for dom in points :
        movie_point.append(dom.text)
    for dom in reviews :
        content = dom.contents[6]  
        content = re.sub("[\n\t]", "", content)   
        content = re.sub("신고", "", content)
        movie_review.append(content)

for i  in range(len(movie_title)):
    print('영화제목:' , movie_title[i])
    print('평점:' , movie_point[i])
    print('리뷰:' , movie_review[i])
    print('-----------------------------------------')
# Out:
# 영화제목: 시동
# 평점: 10
# 리뷰: 적절한 웃음포인트와 감동이 함께하는 영화
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 4
# 리뷰: 극장에서 영화 보고 캣츠(1998) DVD 보게 하는 마술을 보여줌니다.
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 1
# 리뷰: 재미 ㅈㄴ 옶음 절대 보지마라
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 영화 천만 넘긴다에 제 양쪽 불알을 걸겠습니다.배우들 연기도 너무 좋았고 마지막에 눈물도 찔끔났음. 올해 영화 중에는 최고에요
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 배우들 다 원작이랑 싱크로율이 좋아서ㅋㅋ 보는 재미가 확실히 있더라
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 천문 영화관 좀 양보해주지 ?
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 여러 배우분들의 연기가 정말 인상깊었어요 꼭 보세요!!!
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 이정도면 구성력도 있고 잘만들었네요 강추입니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 볼땐 몰랐는데 끝나고 나니까 생각나는 인상 깊었던 영화!
# -----------------------------------------
# 영화제목: 해피 데스데이 2 유
# 평점: 7
# 리뷰: 십대들이 좋아할 영화.
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 전 혼자 봤어요. 대만족입니다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 4
# 리뷰: 아... 골든슬럼버가 이 감독 작품이었네... 한결같아...
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 이거 제 인생영화인데 정말 연기는 물론이고 연출도 미쳤어요 진짜..감동과 웃음과 아주 놓치는 부분이 1도없는 그런 완벽한 영화입니다롱????
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 6
# 리뷰: 와일드라이프는  사실 결국 자신의 선택이라는것...
# -----------------------------------------
# 영화제목: 은지: 돌이킬 수 없는 그녀
# 평점: 5
# 리뷰: 권상우 연기에 열정있었다재미는 그저그럼,,,
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 1
# 리뷰: 좌빨영화 아닌가요 10 자
# -----------------------------------------
# 영화제목: 대부 2
# 평점: 1
# 리뷰: 이 배우가지고 이게 영화냐
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 배우들도 그렇고 스토리도 그렇고 넘 좋았다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 이거 웹툰도 띵작인데 영화도 띵작될 거 같아ㅠㅠ
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 내기준 겨울왕국보다 100배 재밌음ㅠㅠ 이병헌 비주얼, 연기 소름이고 하정우도 존멋!!~~
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 적절한 웃음포인트와 감동이 함께하는 영화
# -----------------------------------------
# 영화제목: 와일드라이프
# 평점: 4
# 리뷰: 극장에서 영화 보고 캣츠(1998) DVD 보게 하는 마술을 보여줌니다.
# -----------------------------------------
# 영화제목: 신의 한 수: 귀수편
# 평점: 1
# 리뷰: 재미 ㅈㄴ 옶음 절대 보지마라
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 영화 천만 넘긴다에 제 양쪽 불알을 걸겠습니다.배우들 연기도 너무 좋았고 마지막에 눈물도 찔끔났음. 올해 영화 중에는 최고에요
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 배우들 다 원작이랑 싱크로율이 좋아서ㅋㅋ 보는 재미가 확실히 있더라
# -----------------------------------------
# 영화제목: 시동
# 평점: 2
# 리뷰: 천문 영화관 좀 양보해주지 ?
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 여러 배우분들의 연기가 정말 인상깊었어요 꼭 보세요!!!
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 이정도면 구성력도 있고 잘만들었네요 강추입니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 볼땐 몰랐는데 끝나고 나니까 생각나는 인상 깊었던 영화!
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 7
# 리뷰: 십대들이 좋아할 영화.
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 9
# 리뷰: 시간가는줄 모르고 봤습니다!! 주연 조연 배우분들 모두 굿굿!!
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 1
# 리뷰: 합리적으로 이득본 사람이 범인이지ㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 진짜 30번을 넘게 봐도 안질린다 ㅋㅋ
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 교훈도 있고 감동도 있고 웃음도 있고
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 희대의 망작 조잡 CG 메모리까지 망쳐버린 쥐어짜는 징징 크리스마스 이브를 저주로 만듬
# -----------------------------------------
# 영화제목: 시동
# 평점: 4
# 리뷰: 정말 내용이 없다..재미도 없다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 생각보다 더 재밌고 감동이~~
# -----------------------------------------
# 영화제목: 해피 데스데이 2 유
# 평점: 9
# 리뷰: 이런 영화가 천만이 넘어야 하는데...
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 오랜만에 보기 좋은 가족 영화가 나온듯~~~
# -----------------------------------------
# 영화제목: 대통령의 7시간
# 평점: 10
# 리뷰: 쇼생크 탈출  이후로  역대작품입니다
# -----------------------------------------
# 영화제목: 공공의 적
# 평점: 9
# 리뷰: ㅋㅋ이건 대박 몰입도 최고다
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 배우들의 연기는 실감나도록 잘했음!!!
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 1
# 리뷰: 캣츠 제대로 즐기려고 OST 넘버들 섭렵하고 엄청난 기대를 안고 갔다..지오디가 6집 전곡을 뮤직비디오로 만들어서 한편의 드라마 형식으로 만들었는데영화 보는 내내 그런 느낌이였음..몇달동안 기대했던 대작이였는데실망이 크네..
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 지루할줄 알았는데 시간 가는줄 모르고 봄
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 지루할틈 없이 빠른진행에 영상미 그리고 배우들의 연기도 다 좋았다
# -----------------------------------------
# 영화제목: 포드 V 페라리
# 평점: 10
# 리뷰: 웃기긴만 영화가 아닙니다 꼭 꼭 보세요
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 믿고 보는 마동석 영화! 언제나 좋네요!
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 기대 1도 안했는 개꿀잼ㅋㅋ 웃고 즐기만한 영화ㅋㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 가출,폭력,미성연자 성매매등 어려운 사회문제를 다뤘지만 무겁지 않게 웃으며 즐길수 있는 가족영화로 잘 만드신거 같습니다 웃고 떠들며 보지만 결국 집나가면 고생한다는 교훈?? 을 주는 좋은 영화라 생각합니다성공하면 좋겠습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 재밌구 웃음 포인트들도 많고ㅋㅋ
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 4
# 리뷰: 예술 10 재미 1 여러의미로 엄청난 영화
# -----------------------------------------
# 영화제목: 블랙머니
# 평점: 8
# 리뷰: 삶에대한 의미도 찾아볼수있는 좋은영화입니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 좋아하는 배우분들 많이나오시고 스토리도 인간적인내용인거같아 보았는데 잘본거같습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 연기도 좋고 소재도 좋고 너무 재미있게 잘봤어요
# -----------------------------------------
# 영화제목: 시동
# 평점: 2
# 리뷰: 이병헌 하정우 전도연ㅜ배우들이 아깝다 ㅠㅠ 감독 뭐하는 사람임?
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 치킨집에 이어서 짜장면집까지ㅋㅋ 올해 넘 배불렀쥐
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 배우님들 연기에 요소요소 재미와 감동 좋음
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 영화 스토리, 평가보고 볼 생각없었는데 공짜표 생겨서 봤습니다이병헌나오고부터 재밌네요 끝까지 몰입해서 봤습니다초반과 중간중간 개연성 없는 장면들이 완성도를 낮추지만 재밌었습니다
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰: 백두산이랑 천문 모두 봤지만. 역시 대배우는 다르더라구요.. 역시 천문!!!! 전 진짜 너무 기대했는지. 백두산은 추천하고 싶지 않을정도로 실망했어요. 형편 없는건 아니지만. 구지... 근데 어제 남편이랑 천문 보고 왔는데. 완전 집중해서.. 시간이 어떻게 간지 모르겠어요. 시간 괜찮으신 분들은 천문에 한번 빠져보세요..^^
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 동재미 다 있어요♡ 배우들 연기도 좋았답니다ㅎㅎ
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 빠른전개! 명품배우들의연기!
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 장영실과 세종의 사랑이야기 잘 보았습니다
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 초반에는 CG가 너무 리얼해서 실감나게 무서웠습니당 끝까지 리얼은 했는데 상식적으로 이해가 안 되는 전개가 몇 가지 숨어 있었던 것 말고는 저는 대만족했습니다. 개그를 좋아하는 배우님들이 만나서 너무 웃음 포인트가 많아서 진짜 웃겼고 깊은 생각 없이만 본다면 비록 재난 영화의 클리셰 덩어리지만 클리셰는 생각도 안 들 정도로 굉장히 재밌고 흥미진진한 이야기였습니다. 마지막에 감동도 엄청나서 눈물도 흘렸네요. 한 가지 불편한 점이 있었다면 하 배우님과 배 배우님의 얼굴 나이 차... 가... 너무 예쁘셔서 좋긴 했지만 전혜진 배우님과 출연 시간은 비슷한 것 같던데 그 두 여자 분이 역할만 바꾸셨으면 더 잘 어울리고 보기 편한 영화가 아니었을까... 싶지만 배우님께서 선택하신 거니 뭐 어쨌든 좋았습니다~ 저는 꼭 보기를 추천하는 바입니다!
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 재밌고 짠한 먹먹함도있고, 아무생각없이 재밌게 봤어어요~
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 기대없이 보았는데~재미와 감동!! 재밋게 웃었습니당ㅎㅎ
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 억지스러운 연출, 개연성 없는 시나리오. 그런데 왜 내 눈에선 계속 눈물이 쏟아지는가
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 재밌으면서도 감동도 있고 그 누구와 봐도 부담없이 볼 수 있는 재밌는 영화
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 재미 감동 최고였던 영화
# -----------------------------------------
# 영화제목: 시동
# 평점: 7
# 리뷰: 기대하고 보지 않았지만 무난하게 스토리 전개나생활애기가 재미나게 보았음.
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 재밌었고 기억에 오래 남을 것 같은 영화임
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰:
# -----------------------------------------
# 영화제목: 시동
# 평점: 5
# 리뷰: 문화의날이라서 5000원내고 본게 참 다행이었다고 생각합니다.재난영화이면 재난에 집중해서 파견된 특수부대와 한국지휘부간의 이야기, 미군과의 갈등에 더 집중해서 긴박함을 조성하는것이 더 재미있었겠다 싶습니다.어떻게든 이리저리 이야기를 만들고자 개연성은 갖다버린 것은 이해합니다만....중간중간 개그치는것과 순옥이와 수지의 등장은 도리어 재난이야기에 집중이 안되게하고 산만하게만 만드는 요소였습니다. 뭐 마지막에 이병헌을 남게하기위한 요소로 등장하였겠지만..도리어 이야기를 산만하게 만들었습니다.
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 별로 기대도 안 했지만 기대 이상으로 재밌었다
# -----------------------------------------
# 영화제목: 두더지
# 평점: 9
# 리뷰: 와 정말 간만에 재밌는 영화 봤어요
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 짱임ㅋㅋㅋ또보고싶다
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 개그는 기대에 못 미치고속터지는 현실은 100퍼 반영....웃으러 갔다가 고구마만 먹고 옴 ㅠㅠㅠ내가 기대한 건 이게 아니었어....
# -----------------------------------------
# 영화제목: 시동
# 평점: 2
# 리뷰: 화려한 배우들 출연으로 기대 했건만 스토리 연결성이나작품성이 기대에 못 미침. ㅠㅠ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 전 잼나던데요.유머도있고 감동도 있고.이병헌이 연기하나는 잘하네요
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 펙터클한 영화도 좋지만 이런 소소한 느낌도 좋다
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 최악입니다 최악 정말 이런 최악이 없습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 주변에 추천하고 싶은 영화에요~
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 거석이형의 존재감은 진짜 미쳤어;;
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 시동 믿고 보세요 재밌습니다ㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 진짜 재미없었음.없는 감동을 자꾸 쥐어 짜내려는 느낌?
# -----------------------------------------
# 영화제목: 백두산
# 평점: 8
# 리뷰: 배우들 연기도 굿 내용도 굿
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 천재를 다룬 영화들 중 이렇게 못만든 영화가 있을 수도..
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 깊이보단 가볍게 웃으며 볼 영화입니다
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 8
# 리뷰: ㅎㅎ 다음에또보고싶네요
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 최민식은 두말할거없지만  한석규 정말연기잘한다. 도대체 한석규는 연기를위해 태어난사람인듯  거기에 신구 선생님 연기도 조연으로 충분히 더해졋다 내용도 끝까지 흥미로웟다
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 백두산에서 하정우역은 하정우가 하기엔 너무 매력발산없는 역이었고 이병헌역을 하정우가 해도 참 좋았을거같다는  생각이 듭니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 7
# 리뷰: 무게감이 있어 관람에 심적 부담감도 있었고 아기돼지 이미지가 무거운 분위기와 잘 매치가 안돼서 어색해보였지만 귀여웠다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 아니 진짜 재밌는데 ㅜㅜㅜ 시지좋고 배우들 연기좋고
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 뻔한 소재인데도 몰입도는 최고 재밌었음!
# -----------------------------------------
# 영화제목: 무한대를 본 남자
# 평점: 10
# 리뷰: 아이들과 즐거운 시간 보내고 왔습니다~~~주비 너무 귀여움요 ㅠㅠ
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 영화가 산으로 가는 느낌천문보세요. 백두산은 천문에 비하면 OOO기 폐급영화입니다.
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 초반에는 재미없어서 '아 잠들것같은데' 하는순간.. 그지점부터 집중하게됐다.하정우가 연기를 이렇게 못했었나에 놀랐고수지의 청순함에 놀랐고 수지가 우는장면에서 사람들이 울어줬어야 하는것같은데 솔직히 감정전달이 잘 안되다보니 감동이 오다말았고.. 이병헌의 연기력은 말할것도없어서.. 이병헌 아니었으면 폭망했을것같아요... 하정우배우님은... 그 걷기모임에 있는 지인들 그만좀 챙겨요 ㅠ ㅠ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 믿고 보는 배우들ㅋㅋ 예고편떳을때부터 재밌었다구ㅋㅋ
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 어릴때 가장 감명깊게 보았던 라이온킹아이랑 다시 봤네요영상미 넘 좋아요
# -----------------------------------------
# 영화제목: 검은 사제들
# 평점: 10
# 리뷰: 마블리 거석이형이 한건했다ㅋㅋㅋ 역대급 인캐bb
# -----------------------------------------
# 영화제목: 백두산
# 평점: 6
# 리뷰: 난 재미있게봤엉 나쁘지않던데
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 도대체 뭘 전달하려는 거죠?혹시..고양이는 개가 아니다? ㅋㅋㅋ스크린 찢고 싶었음 ㅋㅋㅋㅋ
# -----------------------------------------
# 영화제목: 신비아파트 극장판 하늘도깨비 대 요르문간드
# 평점: 1
# 리뷰: 진짜.. 노잼..뮤지컬영화보면서 졸기는 처음..
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 감동적인 영화였어요 기대안했는데 최고~~
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 기대했던거 이상으로 재밌었고 감동적
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰:
# -----------------------------------------
# 영화제목: 라이온 킹
# 평점: 10
# 리뷰: 이걸 멜로물이라고 비평하는사람들은 뭐지ㅋㅋ간만에 볼만한 영화였음많은 생각이 들게 했네요깊이가없는사람들은 재미가없다고느끼겠죠이 영화는 느린 전개가 잘 어울립니다감정선을 더 잘 느낄수 있거든요저는 재밌게 잘 봤습니다실제에 근거한 영화라 몰입도가 좋았음다시 되새겨봐도 울컥하네요
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 연기는 정말 빼놓을수 없어요!!  최민식 배우님의 묵직함 때문인지...장영실역으로는 살짝 아쉽네요 .. 사실 영의정 상이잖아요 ㅎㅎ예측되는 내용이었지만 연기 갑 배우들이 모여있으니 탄탄해서 볼만했습니다!
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 연기 연출 시나리오 모두 다 최고
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 9
# 리뷰: 생각보다 재밌게 봤음
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 1
# 리뷰: 감독이 골든슬럼버라는 희대의 잡탕 만들어낸 감독이라할때 눈치챘다ㅋㅋ
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰: 허진호 감독님 앞으로 믿고볼랍니다~ 너무너무 잘만듬
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 다들 재밋게 봤습니다 감사합니다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 한석규님 10점 드립니다
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰:
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 6
# 리뷰: 여자혼자 외딴섬에 스킨스쿠버한다고 온거자체가 말이안되고 영화초반에 여교사강간사건이랑 사람들이 자기를 강간하려고 모의하는걸 몰래듣고도 섬을 안나가는것도 어이없음 혼자 사건조사하러 다니질않나 ㅋㅋ 데체 섬을 왜 안나가는거야? 그래도 미스터투 박선우님때문에 별점좀준다.
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 정말 잘만든 것 같음., 이정도면 오백만 이상은 거뜬
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 7
# 리뷰: 가족을 지키기 위해 인간성과 가OO지 버린 남자의 이야기
# -----------------------------------------
# 영화제목: 포드 V 페라리
# 평점: 10
# 리뷰: 진짜 인정할수밖에 없는 영화 ㅋㅋ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 전 혼자 봤어요. 대만족입니다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 4
# 리뷰: 아... 골든슬럼버가 이 감독 작품이었네... 한결같아...
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 이거 제 인생영화인데 정말 연기는 물론이고 연출도 미쳤어요 진짜..감동과 웃음과 아주 놓치는 부분이 1도없는 그런 완벽한 영화입니다롱????
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 6
# 리뷰: 와일드라이프는  사실 결국 자신의 선택이라는것...
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 5
# 리뷰: 권상우 연기에 열정있었다재미는 그저그럼,,,
# -----------------------------------------
# 영화제목: 은지: 돌이킬 수 없는 그녀
# 평점: 1
# 리뷰: 좌빨영화 아닌가요 10 자
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 1
# 리뷰: 이 배우가지고 이게 영화냐
# -----------------------------------------
# 영화제목: 대부 2
# 평점: 10
# 리뷰: 배우들도 그렇고 스토리도 그렇고 넘 좋았다
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 이거 웹툰도 띵작인데 영화도 띵작될 거 같아ㅠㅠ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 내기준 겨울왕국보다 100배 재밌음ㅠㅠ 이병헌 비주얼, 연기 소름이고 하정우도 존멋!!~~
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 적절한 웃음포인트와 감동이 함께하는 영화
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 4
# 리뷰: 극장에서 영화 보고 캣츠(1998) DVD 보게 하는 마술을 보여줌니다.
# -----------------------------------------
# 영화제목: 와일드라이프
# 평점: 1
# 리뷰: 재미 ㅈㄴ 옶음 절대 보지마라
# -----------------------------------------
# 영화제목: 신의 한 수: 귀수편
# 평점: 10
# 리뷰: 영화 천만 넘긴다에 제 양쪽 불알을 걸겠습니다.배우들 연기도 너무 좋았고 마지막에 눈물도 찔끔났음. 올해 영화 중에는 최고에요
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 배우들 다 원작이랑 싱크로율이 좋아서ㅋㅋ 보는 재미가 확실히 있더라
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 천문 영화관 좀 양보해주지 ?
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 여러 배우분들의 연기가 정말 인상깊었어요 꼭 보세요!!!
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 이정도면 구성력도 있고 잘만들었네요 강추입니다
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 볼땐 몰랐는데 끝나고 나니까 생각나는 인상 깊었던 영화!
# -----------------------------------------
# 영화제목: 시동
# 평점: 7
# 리뷰: 십대들이 좋아할 영화.
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 9
# 리뷰: 시간가는줄 모르고 봤습니다!! 주연 조연 배우분들 모두 굿굿!!
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 1
# 리뷰: 합리적으로 이득본 사람이 범인이지ㅋㅋ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 진짜 30번을 넘게 봐도 안질린다 ㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 교훈도 있고 감동도 있고 웃음도 있고
# -----------------------------------------
# 영화제목: 백두산
# 평점: 1
# 리뷰: 희대의 망작 조잡 CG 메모리까지 망쳐버린 쥐어짜는 징징 크리스마스 이브를 저주로 만듬
# -----------------------------------------
# 영화제목: 시동
# 평점: 4
# 리뷰: 정말 내용이 없다..재미도 없다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 생각보다 더 재밌고 감동이~~
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 이런 영화가 천만이 넘어야 하는데...
# -----------------------------------------
# 영화제목: 해피 데스데이 2 유
# 평점: 10
# 리뷰: 오랜만에 보기 좋은 가족 영화가 나온듯~~~
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 쇼생크 탈출  이후로  역대작품입니다
# -----------------------------------------
# 영화제목: 대통령의 7시간
# 평점: 9
# 리뷰: ㅋㅋ이건 대박 몰입도 최고다
# -----------------------------------------
# 영화제목: 공공의 적
# 평점: 8
# 리뷰: 배우들의 연기는 실감나도록 잘했음!!!
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 캣츠 제대로 즐기려고 OST 넘버들 섭렵하고 엄청난 기대를 안고 갔다..지오디가 6집 전곡을 뮤직비디오로 만들어서 한편의 드라마 형식으로 만들었는데영화 보는 내내 그런 느낌이였음..몇달동안 기대했던 대작이였는데실망이 크네..
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰: 지루할줄 알았는데 시간 가는줄 모르고 봄
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 지루할틈 없이 빠른진행에 영상미 그리고 배우들의 연기도 다 좋았다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 웃기긴만 영화가 아닙니다 꼭 꼭 보세요
# -----------------------------------------
# 영화제목: 포드 V 페라리
# 평점: 10
# 리뷰: 믿고 보는 마동석 영화! 언제나 좋네요!
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 기대 1도 안했는 개꿀잼ㅋㅋ 웃고 즐기만한 영화ㅋㅋㅋ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 가출,폭력,미성연자 성매매등 어려운 사회문제를 다뤘지만 무겁지 않게 웃으며 즐길수 있는 가족영화로 잘 만드신거 같습니다 웃고 떠들며 보지만 결국 집나가면 고생한다는 교훈?? 을 주는 좋은 영화라 생각합니다성공하면 좋겠습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 재밌구 웃음 포인트들도 많고ㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 4
# 리뷰: 예술 10 재미 1 여러의미로 엄청난 영화
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 8
# 리뷰: 삶에대한 의미도 찾아볼수있는 좋은영화입니다
# -----------------------------------------
# 영화제목: 블랙머니
# 평점: 10
# 리뷰: 좋아하는 배우분들 많이나오시고 스토리도 인간적인내용인거같아 보았는데 잘본거같습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 연기도 좋고 소재도 좋고 너무 재미있게 잘봤어요
# -----------------------------------------
# 영화제목: 시동
# 평점: 2
# 리뷰: 이병헌 하정우 전도연ㅜ배우들이 아깝다 ㅠㅠ 감독 뭐하는 사람임?
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 치킨집에 이어서 짜장면집까지ㅋㅋ 올해 넘 배불렀쥐
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 배우님들 연기에 요소요소 재미와 감동 좋음
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 영화 스토리, 평가보고 볼 생각없었는데 공짜표 생겨서 봤습니다이병헌나오고부터 재밌네요 끝까지 몰입해서 봤습니다초반과 중간중간 개연성 없는 장면들이 완성도를 낮추지만 재밌었습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 백두산이랑 천문 모두 봤지만. 역시 대배우는 다르더라구요.. 역시 천문!!!! 전 진짜 너무 기대했는지. 백두산은 추천하고 싶지 않을정도로 실망했어요. 형편 없는건 아니지만. 구지... 근데 어제 남편이랑 천문 보고 왔는데. 완전 집중해서.. 시간이 어떻게 간지 모르겠어요. 시간 괜찮으신 분들은 천문에 한번 빠져보세요..^^
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰: 동재미 다 있어요♡ 배우들 연기도 좋았답니다ㅎㅎ
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 빠른전개! 명품배우들의연기!
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 장영실과 세종의 사랑이야기 잘 보았습니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 초반에는 CG가 너무 리얼해서 실감나게 무서웠습니당 끝까지 리얼은 했는데 상식적으로 이해가 안 되는 전개가 몇 가지 숨어 있었던 것 말고는 저는 대만족했습니다. 개그를 좋아하는 배우님들이 만나서 너무 웃음 포인트가 많아서 진짜 웃겼고 깊은 생각 없이만 본다면 비록 재난 영화의 클리셰 덩어리지만 클리셰는 생각도 안 들 정도로 굉장히 재밌고 흥미진진한 이야기였습니다. 마지막에 감동도 엄청나서 눈물도 흘렸네요. 한 가지 불편한 점이 있었다면 하 배우님과 배 배우님의 얼굴 나이 차... 가... 너무 예쁘셔서 좋긴 했지만 전혜진 배우님과 출연 시간은 비슷한 것 같던데 그 두 여자 분이 역할만 바꾸셨으면 더 잘 어울리고 보기 편한 영화가 아니었을까... 싶지만 배우님께서 선택하신 거니 뭐 어쨌든 좋았습니다~ 저는 꼭 보기를 추천하는 바입니다!
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 재밌고 짠한 먹먹함도있고, 아무생각없이 재밌게 봤어어요~
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 기대없이 보았는데~재미와 감동!! 재밋게 웃었습니당ㅎㅎ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 억지스러운 연출, 개연성 없는 시나리오. 그런데 왜 내 눈에선 계속 눈물이 쏟아지는가
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 재밌으면서도 감동도 있고 그 누구와 봐도 부담없이 볼 수 있는 재밌는 영화
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰: 재미 감동 최고였던 영화
# -----------------------------------------
# 영화제목: 시동
# 평점: 7
# 리뷰: 기대하고 보지 않았지만 무난하게 스토리 전개나생활애기가 재미나게 보았음.
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 재밌었고 기억에 오래 남을 것 같은 영화임
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 10
# 리뷰:
# -----------------------------------------
# 영화제목: 백두산
# 평점: 5
# 리뷰: 문화의날이라서 5000원내고 본게 참 다행이었다고 생각합니다.재난영화이면 재난에 집중해서 파견된 특수부대와 한국지휘부간의 이야기, 미군과의 갈등에 더 집중해서 긴박함을 조성하는것이 더 재미있었겠다 싶습니다.어떻게든 이리저리 이야기를 만들고자 개연성은 갖다버린 것은 이해합니다만....중간중간 개그치는것과 순옥이와 수지의 등장은 도리어 재난이야기에 집중이 안되게하고 산만하게만 만드는 요소였습니다. 뭐 마지막에 이병헌을 남게하기위한 요소로 등장하였겠지만..도리어 이야기를 산만하게 만들었습니다.
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 별로 기대도 안 했지만 기대 이상으로 재밌었다
# -----------------------------------------
# 영화제목: 시동
# 평점: 9
# 리뷰: 와 정말 간만에 재밌는 영화 봤어요
# -----------------------------------------
# 영화제목: 두더지
# 평점: 9
# 리뷰: 짱임ㅋㅋㅋ또보고싶다
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 개그는 기대에 못 미치고속터지는 현실은 100퍼 반영....웃으러 갔다가 고구마만 먹고 옴 ㅠㅠㅠ내가 기대한 건 이게 아니었어....
# -----------------------------------------
# 영화제목: 시동
# 평점: 2
# 리뷰: 화려한 배우들 출연으로 기대 했건만 스토리 연결성이나작품성이 기대에 못 미침. ㅠㅠ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 전 잼나던데요.유머도있고 감동도 있고.이병헌이 연기하나는 잘하네요
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 펙터클한 영화도 좋지만 이런 소소한 느낌도 좋다
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 최악입니다 최악 정말 이런 최악이 없습니다
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 주변에 추천하고 싶은 영화에요~
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 거석이형의 존재감은 진짜 미쳤어;;
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 시동 믿고 보세요 재밌습니다ㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 진짜 재미없었음.없는 감동을 자꾸 쥐어 짜내려는 느낌?
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: 배우들 연기도 굿 내용도 굿
# -----------------------------------------
# 영화제목: 백두산
# 평점: 2
# 리뷰: 천재를 다룬 영화들 중 이렇게 못만든 영화가 있을 수도..
# -----------------------------------------
# 영화제목: 백두산
# 평점: 9
# 리뷰: 깊이보단 가볍게 웃으며 볼 영화입니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 8
# 리뷰: ㅎㅎ 다음에또보고싶네요
# -----------------------------------------
# 영화제목: 캣츠
# 평점: 10
# 리뷰: 최민식은 두말할거없지만  한석규 정말연기잘한다. 도대체 한석규는 연기를위해 태어난사람인듯  거기에 신구 선생님 연기도 조연으로 충분히 더해졋다 내용도 끝까지 흥미로웟다
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 백두산에서 하정우역은 하정우가 하기엔 너무 매력발산없는 역이었고 이병헌역을 하정우가 해도 참 좋았을거같다는  생각이 듭니다
# -----------------------------------------
# 영화제목: 시동
# 평점: 7
# 리뷰: 무게감이 있어 관람에 심적 부담감도 있었고 아기돼지 이미지가 무거운 분위기와 잘 매치가 안돼서 어색해보였지만 귀여웠다
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 아니 진짜 재밌는데 ㅜㅜㅜ 시지좋고 배우들 연기좋고
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 9
# 리뷰: 뻔한 소재인데도 몰입도는 최고 재밌었음!
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 아이들과 즐거운 시간 보내고 왔습니다~~~주비 너무 귀여움요 ㅠㅠ
# -----------------------------------------
# 영화제목: 무한대를 본 남자
# 평점: 1
# 리뷰: 영화가 산으로 가는 느낌천문보세요. 백두산은 천문에 비하면 OOO기 폐급영화입니다.
# -----------------------------------------
# 영화제목: 시동
# 평점: 6
# 리뷰: 초반에는 재미없어서 '아 잠들것같은데' 하는순간.. 그지점부터 집중하게됐다.하정우가 연기를 이렇게 못했었나에 놀랐고수지의 청순함에 놀랐고 수지가 우는장면에서 사람들이 울어줬어야 하는것같은데 솔직히 감정전달이 잘 안되다보니 감동이 오다말았고.. 이병헌의 연기력은 말할것도없어서.. 이병헌 아니었으면 폭망했을것같아요... 하정우배우님은... 그 걷기모임에 있는 지인들 그만좀 챙겨요 ㅠ ㅠ
# -----------------------------------------
# 영화제목: 시동
# 평점: 10
# 리뷰: 믿고 보는 배우들ㅋㅋ 예고편떳을때부터 재밌었다구ㅋㅋ
# -----------------------------------------
# 영화제목: 천문: 하늘에 묻는다
# 평점: 9
# 리뷰: 어릴때 가장 감명깊게 보았던 라이온킹아이랑 다시 봤네요영상미 넘 좋아요
# -----------------------------------------
# 영화제목: 백두산
# 평점: 10
# 리뷰: 마블리 거석이형이 한건했다ㅋㅋㅋ 역대급 인캐bb
# -----------------------------------------
# 영화제목: 검은 사제들
# 평점: 6
# 리뷰: 난 재미있게봤엉 나쁘지않던데
# -----------------------------------------
# 영화제목: 백두산
# 평점: 1
# 리뷰: 도대체 뭘 전달하려는 거죠?혹시..고양이는 개가 아니다? ㅋㅋㅋ스크린 찢고 싶었음 ㅋㅋㅋㅋ
# -----------------------------------------
# 영화제목: 시동
# 평점: 1
# 리뷰: 진짜.. 노잼..뮤지컬영화보면서 졸기는 처음..
# -----------------------------------------

# %%
#URL 조인 결과 출력 , 특정 도메인 아래 문서에 대한 탐색 시 용이하다.
from urllib.parse import urljoin
base = "http://example.com/html/a.html"
print( urljoin(base, "b.html") )
print( urljoin(base, "sub/c.html") )
print( urljoin(base, "../index.html") )
print( urljoin(base, "../img/hoge.png") )
print( urljoin(base, "../css/hoge.css") )
print( urljoin(base, "/hoge.html") )
print( urljoin(base, "http://otherExample.com/wiki") )
print( urljoin(base, "//anotherExample.org/test") )
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/c.html
# http://example.com/index.html
# http://example.com/img/hoge.png
# http://example.com/css/hoge.css
# http://example.com/hoge.html
# http://otherExample.com/wiki
# http://anotherExample.org/test

# %%
# 파이썬 매뉴얼을 재귀적으로 다운받는 프로그램
from bs4 import BeautifulSoup
from urllib.request import *
from urllib.parse import *
from os import makedirs
import os.path, time, re
# 이미 처리한 파일인지 확인하기 위한 변수 
proc_files = {}

base = "http://example.com/html/a.html"
url = 'http://10.5.4.100:8080/python.html'
req = requests.get(url)
html = req.text

# HTML 내부에 있는 링크를 추출하는 함수 
def enum_links(html, base):
    soup = BeautifulSoup(html, "html.parser")
    links = soup.select("link[rel='stylesheet']") # CSS
    links += soup.select("a[href]") # 링크
    result = []
    # href 속성을 추출하고, 링크를 절대 경로로 변환 
    for a in links:
        href = a.attrs['href']
        url = urljoin(base, href) #상대 경로(path 매개변수)가 http://등으로 시작한다면 기본 URL(base 매개변수)을 무시하고, 두번째 매개변수에 지정한 URL을 리턴
        result.append(url)
    return result


list_link = enum_links(html,base)
for i in list_link:
    print(i)
# Out:
# http://example.com/html/note/day11.txt
# http://example.com/html/note/day12.txt
# http://example.com/html/note/pandas_excercise4.txt
# http://example.com/html/book/BeautifulSoup.pptx
# http://example.com/html/note/web_scrapying_excercise.txt
# http://example.com/html/note/day13.txt
# http://example.com/html/note/day1.txt
# http://example.com/html/python_basic.zip
# http://example.com/html/note/day2.txt
# http://example.com/html/note/exercise1.txt
# http://example.com/html/note/yesterday.txt
# http://example.com/html/note/exercise2.txt
# http://example.com/html/note/day3.txt
# http://example.com/html/note/excercise3.txt
# http://example.com/html/note/day4.txt
# http://example.com/html/python_etc.pptx
# http://example.com/html/note/python_programming_exercise.pptx
# http://example.com/html/note/day5.txt
# http://example.com/html/win64_11gR2_database_1of2.zip
# http://example.com/html/win64_11gR2_database_2of2.zip
# http://example.com/html/book/anaconda.pptx
# http://example.com/html/note/day6.txt
# http://example.com/html/book/python numpy.pptx
# http://example.com/html/note/numpy_excercise1.txt
# http://example.com/html/note/day7.txt
# http://example.com/html/datas.zip
# http://example.com/html/note/day8.txt
# http://example.com/html/note/pandas_excercise1.txt
# http://example.com/html/note/pandas_excercise2.txt
# http://example.com/html/note/day9.txt
# http://example.com/html/book/_pandas.pptx
# http://example.com/html/book/workshop1.pptx
# http://example.com/html/note/pandas_excercise3.txt
# http://example.com/html/game_ws1_datas.zip
# http://example.com/html/note/day10.txt
# http://example.com/html/a.html
# http://example.com/html/a.html
# http://example.com/html/a.html
# http://example.com/html/a.html
# http://example.com/html/a.html
# http://example.com/html/a.html

# %%
############### 파이썬 매뉴얼을 재귀적으로 다운받는 프로그램#######################
# 파이썬 매뉴얼을 재귀적으로 다운받는 프로그램
# 모듈 읽어 들이기 
from bs4 import BeautifulSoup
from urllib.request import *
from urllib.parse import *
from os import makedirs
import os.path, time, re
# 이미 처리한 파일인지 확인하기 위한 변수 
proc_files = {}

# HTML 내부에 있는 링크를 추출하는 함수 
def enum_links(html, base):
    soup = BeautifulSoup(html, "html.parser")
    links = soup.select("link[rel='stylesheet']") # CSS
    links += soup.select("a[href]") # 링크
    result = []
    # href 속성을 추출하고, 링크를 절대 경로로 변환 
    for a in links:
        href = a.attrs['href']
        url = urljoin(base, href)
        result.append(url)
    return result

# 파일을 다운받고 저장하는 함수 
def download_file(url):
    o = urlparse(url)
    savepath = "./" + o.netloc + o.path
    if re.search(r"/$", savepath): # 폴더라면 index.html
        savepath += "index.html"
    savedir = os.path.dirname(savepath)
    # 모두 다운됐는지 확인
    if os.path.exists(savepath): return savepath
    # 다운받을 폴더 생성
    if not os.path.exists(savedir):
        print("mkdir=", savedir)
        makedirs(savedir)
    # 파일 다운받기 
    try:
        print("download=", url)
        urlretrieve(url, savepath)
        time.sleep(1) # 1초 휴식 
        return savepath
    except:
        print("다운 실패: ", url)
        return None  
      
# HTML을 분석하고 다운받는 함수 
def analyze_html(url, root_url):
    savepath = download_file(url)
    if savepath is None: return
    if savepath in proc_files: return # 이미 처리됐다면 실행하지 않음 
    proc_files[savepath] = True
    print("analyze_html=", url)
    # 링크 추출 --- (※10)
    html = open(savepath, "r", encoding="utf-8").read()
    links = enum_links(html, url)
    for link_url in links:
        # 링크가 루트 이외의 경로를 나타낸다면 무시 
        if link_url.find(root_url) != 0:
            if not re.search(r".css$", link_url): continue
        # HTML이라면
        if re.search(r".(html|htm)$", link_url):
            # 재귀적으로 HTML 파일 분석하기
            analyze_html(link_url, root_url)
            continue
        # 기타 파일
        download_file(link_url)
if __name__ == "__main__":
    # URL에 있는 모든 것 다운받기 
    url = "https://docs.python.org/3.5/library/"
    analyze_html(url, url)

# %%
#한빛출판네트워크에 로그인 해보기

import requests            # 로그인을 위한 모듈 추출하기
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# 아이디와 비밀번호 지정하기
USER = "아이디"
PASS = "비밀번호!"

session = requests.session()  # 세션 시작하기 
print(session)
login_info = {                     # 로그인 정보
    "m_id": USER,                 # 아이디 지정
    "m_passwd": PASS           # 비밀번호 지정
}
url_login = "http://www.hanbit.co.kr/member/login_proc.php"
res = session.post(url_login, data=login_info)
res.raise_for_status()            # 오류가 발생하면 예외가 발생합니다.

url_mypage = "http://www.hanbit.co.kr/myhanbit/myhanbit.html"  # 마이페이지에 접근하기  
res = session.get(url_mypage)
res.raise_for_status()

soup = BeautifulSoup(res.text,'html.parser')
#print(soup)
mileage = soup.select_one('.mileage_section1 > dd > span').get_text()
ecoin = soup.select_one('.mileage_section2 > dd > span').get_text()
print("마일리지 : "+mileage )
print("이코인 : "+ecoin )
# Out:
# <requests.sessions.Session object at 0x000001EAAB377708>
# 마일리지 : 2,000
# 이코인 : 0
